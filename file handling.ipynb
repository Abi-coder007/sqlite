# %%
with open ("example.text","w") as file:
    file.write("hello my name is abishek")

# %%
with open ("example.text","r") as file:
    result = file.read()

# %%
print(result)
# Out:
# hello my name is abishek
